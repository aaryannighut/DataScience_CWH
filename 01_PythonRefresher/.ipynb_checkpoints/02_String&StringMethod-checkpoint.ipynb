# %%
name = "Aaryan"

# %%
name
# Out:
# 'Aaryan'

# %%
name.upper()
# Out:
# 'AARYAN'

# %%
name.endswith("an")
# Out:
# True

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.lower()
# Out:
# 'aaryan'

# %%
name.count("a")
# Out:
# 2

# %%
name.count("A")
# Out:
# 1

# %%
s = "AaryanNighut"
print(len(s))
# Out:
# 12

# %%
s[0:5]
# Out:
# 'Aarya'

# %%
s[1:-1]
# Out:
# 'aryanNighu'

# %%
s[1:11]
# Out:
# 'aryanNighu'

# %%
s[-11:-1]
# Out:
# 'aryanNighu'

# %%
s = "AaryanNighut"
print(s.lower())
# Out:
# aaryannighut

# %%
s = "AaryanNighut"
print(s.upper())
# Out:
# AARYANNIGHUT

# %%
s = "  AaryanNighut  "
print(s.strip())
# Out:
# AaryanNighut

# %%
s = "AaryanNighut"
print(s.replace("Aaryan", "Aarya"))
# Out:
# AaryaNighut

# %%
s = "Aaryan,Nighut"
print(s.split(","))
# Out:
# ['Aaryan', 'Nighut']

# %%
words = ["Aaryan", "Nighut"]
print(" ".join(words))
# Out:
# Aaryan Nighut

# %%
s = "AaryanNighut"
print(s.find("Nighut"))
# Out:
# 6

# %%
s = "banana"
print(s.count("a"))
# Out:
# 3

# %%
s = "AaryanNighut"
print(s.startswith("Aaryan"))
# Out:
# True

# %%
s = "AaryanNighut"
print(s.endswith("Nighut"))
# Out:
# True

# %%
s = "python"
print(s.capitalize())
# Out:
# Python

# %%
s = "python programming"
print(s.title())
# Out:
# Python Programming

# %%
s = "Python"
print(s.isalpha())
# Out:
# True

# %%
s = "12345"
print(s.isdigit())
# Out:
# True

# %%
s = "Python123"
print(s.isalnum())
# Out:
# True
