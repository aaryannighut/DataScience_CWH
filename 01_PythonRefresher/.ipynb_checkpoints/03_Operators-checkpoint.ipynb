# %%
# Arithmetic Operators

# %%
a = 11
b = 5

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# 6

# %%
a * b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a**b
# Out:
# 161051

# %%
a%b
# Out:
# 1

# %%
# Comparison Operators

# %%
a = 45

# %%
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
c = 3

# %%
a == c # is a equal to c?
# Out:
# False

# %%
a != c
# Out:
# True

# %%
a = 5
b = 5

# %%
a == b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
# Logical Operators

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
# Bitwise Operators

# %%
a = 5
b = 3

# %%
a & b
# Out:
# 1

# %%
a | b
# Out:
# 7

# %%
# Assignment Operators

# %%
a = 45

# %%
a += 4

# %%
a
# Out:
# 49

# %%
a -= 4

# %%
a
# Out:
# 45

# %%
a *= 4

# %%
a
# Out:
# 180
