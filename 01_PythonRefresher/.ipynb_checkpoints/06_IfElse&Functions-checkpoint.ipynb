# %%
a = 400

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %%
a = 41
if a>50:
    print("greater than 50")
elif(a>40):
    print("greater than 40")
elif(a>30):
    print("greater than 30")
else:
    print("Done!")
# Out:
# greater than 40

# %%
# Function

# %%
def avg(a, b):
    return (a+b)/2

# %%
avg(4,6)
# Out:
# 5.0

# %%
def greet():
    print("Hello good morning")

# %%
greet()
# Out:
# Hello good morning
