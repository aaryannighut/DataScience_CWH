# %%
l = [3, 5, 23, 3]

# %%
l[0]
# Out:
# 3

# %%
l[0] = 4

# %%
l
# Out:
# [4, 5, 23, 3]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 3, 9]

# %%
l2 = [5, 7]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 3, 9, 5, 7]

# %%
l.insert(1, 200)  # Insert 200 at index 1

# %%
l
# Out:
# [4, 200, 5, 23, 3, 9, 5, 7]

# %%
number = l.pop(4)

# %%
number
# Out:
# 3

# %%
l
# Out:
# [4, 200, 5, 23, 9, 5, 7]

# %%
l.index(4)
# Out:
# 0

# %%
l.index(23)
# Out:
# 3

# %%
l.append(4)

# %%
l
# Out:
# [4, 200, 5, 23, 9, 5, 7, 4]

# %%
l.count(4)
# Out:
# 2

# %%
l.sort()  # changes and sort the original list in ascending order

# %%
l
# Out:
# [4, 4, 5, 5, 7, 9, 23, 200]

# %%
sorted(l)
# Out:
# [4, 4, 5, 5, 7, 9, 23, 200]

# %%
newl = [2, 6, 1, 21, 6]

# %%
sorted(newl)  # Returns a new list which is soretd version of the original list
# Out:
# [1, 2, 6, 6, 21]

# %%
newl
# Out:
# [2, 6, 1, 21, 6]

# %%
y = [1, 2, True, False, [4, 7]]

# %%
y
# Out:
# [1, 2, True, False, [4, 7]]

# %%
y[4]
# Out:
# [4, 7]

# %%
y[4][0]
# Out:
# 4

# %%
y[4][1]
# Out:
# 7

# %%
list1 = [4, 32, 12]

# %%
list2 = [3, 1, 8]

# %%
list1 + list2
# Out:
# [4, 32, 12, 3, 1, 8]

# %%
list1
# Out:
# [4, 32, 12]

# %%
list2
# Out:
# [3, 1, 8]

# %%
if 3 in list2:
    print("yes")
# Out:
# yes

# %%
if 33 in list2:
    print("yes")

# %%
3 in list2
# Out:
# True

# %%
33 in list2
# Out:
# False

# %%
s = "jack-jill-shubham-kirti-javed-salman-akshay"

# %%
s.split("-")
# Out:
# ['jack', 'jill', 'shubham', 'kirti', 'javed', 'salman', 'akshay']
