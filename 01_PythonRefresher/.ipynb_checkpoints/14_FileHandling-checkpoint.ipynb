# %%
f = open("text.txt" , "r")

# %%
f.read()
# Out:
# 'Aaryan\nis \ngood\nboy\n'

# %%
s = "This is a nice way to learn Data Science"

# %%
f.close()

# %%
f = open("aaryan.txt", "w")

# %%
f.write(s)
# Out:
# 40

# %%
f.close()
