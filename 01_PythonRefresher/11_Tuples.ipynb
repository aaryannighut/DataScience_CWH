# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t = (5, 64, 23, 23)

# %%
t
# Out:
# (5, 64, 23, 23)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 64

# %%
 # t[1] = 34  # Not Possible

# %%
# Packing
person = ("Alice", 25, "Engineer")

# Unpacking
name, age, profession = person

# %%
name
# Out:
# 'Alice'

# %%
age
# Out:
# 25

# %%
profession
# Out:
# 'Engineer'
