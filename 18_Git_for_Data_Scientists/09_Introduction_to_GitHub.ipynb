# %% [markdown]
# # Introduction to GitHub
#
# ---
#
# A beginner-friendly overview of GitHub, covering its purpose as a platform for version control, collaboration, and code hosting. Explains key features like repositories, commits, branches, and pull requests, and highlights how developers use GitHub to work together efficiently on projects.
