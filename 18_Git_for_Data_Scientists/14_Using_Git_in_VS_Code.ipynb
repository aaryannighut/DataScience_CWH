# %% [markdown]
# # Using Git in VS Code
#
# ---
#
# Using Git in VS Code simplifies version control directly within the editor. You can initialize repositories, clone projects, and manage branches without leaving VS Code.
